# %%
from NETWORK_BUILDER import build_network

net, nagents, start, stop = build_network("histories.csv", "Epigames_2")

# %%
import starsim as ss

# %%
sim = ss.Sim(n_agents = nagents, start=start, stop=stop, dt=ss.days(1), networks=net)

sim.run()
# Out:
# Initializing sim with 459 agents
# CHECK: 0 <class 'numpy.int64'> 0 <class 'int'> True
#   Running 2025.11.16 ( 0/16) (0.00 s)  •——————————————————— 6%
# CHECK: 1 <class 'numpy.int64'> 0 <class 'int'> False
# CHECK: 1 <class 'numpy.int64'> 1 <class 'int'> True
# CHECK: 2 <class 'numpy.int64'> 2 <class 'int'> True
# CHECK: 3 <class 'numpy.int64'> 3 <class 'int'> True
# CHECK: 4 <class 'numpy.int64'> 4 <class 'int'> True
# CHECK: 5 <class 'numpy.int64'> 5 <class 'int'> True
# CHECK: 6 <class 'numpy.int64'> 6 <class 'int'> True
# CHECK: 7 <class 'numpy.int64'> 7 <class 'int'> True
# CHECK: 8 <class 'numpy.int64'> 8 <class 'int'> True
# CHECK: 9 <class 'numpy.int64'> 9 <class 'int'> True
#   Running 2025.11.26 (10/16) (14.92 s)  •••••••••••••——————— 69%
# CHECK: 10 <class 'numpy.int64'> 10 <class 'int'> True
# CHECK: 11 <class 'numpy.int64'> 11 <class 'int'> True
# CHECK: 12 <class 'numpy.int64'> 12 <class 'int'> True
# CHECK: 13 <class 'numpy.int64'> 13 <class 'int'> True
# ...

# %%
import sys
sys.path.insert(0, "/Users/ava/Desktop/starsim")
import starsim
print(starsim.__file__)
# Out:
# /Users/ava/Desktop/starsim/starsim/__init__.py
